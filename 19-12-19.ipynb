# %%
#include <stdio.h>
void main()
{
    int c;
    c=20.0/200*200;
    printf("%d",c);
}

#include <stdio.h>
void main()
{
    int c;
    c=(float)20/200*200;
    printf("%d",c);
}

# %%
# print 1 to 100
#include <stdio.h>
void main()
{
    int n;
    scanf("%d",&n);
    if(n==2||n==3||n==5||n==7)
     printf("prime number");
     else if(n%2!=0&&n%3!=0&&n%5!=0&&n%7!=0)
    printf("prime number");
    else
    printf("not a prime number");
}


#include <stdio.h>
void main()
{
 int a,b,op;
 scanf("%d%d",&a,&b);
 scanf("%d",&op);
 switch(op)
 {
     case 1:printf("%d",a+b);break;
     case 2:printf("%d",a-b);break;
     case 3:printf("%d",a*b);break;
     case 4:printf("%d",a/b);break;
     case 5:printf("%d",a%b);break;
     default:printf("inavlid input");break;
 }
 }

#include <stdio.h>
void main()
{
 int a,b;
 char op;
 scanf("%d%d",&a,&b);
 scanf(" %c",&op);
 switch(op)
 {
     case '+':printf("%d",a+b);break;
     case '-':printf("%d",a-b);break;
     case '*':printf("%d",a*b);break;
     case '/':printf("%d",a/b);break;
     case '%':printf("%d",a%b);break;
     default:printf("inavlid input");break;
 }
 }

# %%
# to print odd numbers
#include<stdio.h>
void main()
{
    int i;
    for(i=1;i<20;i+=2)
    printf("%d",i);
}
#include<stdio.h>
void main()
{
    int i;
    for(i=0;i<20;i+=2)
    printf("%d",i);
}
# to print even numbers
#include<stdio.h>
void main()
{
    int i;
    for(i=0;i<20;i+=2)
    printf("%d",i);
}

# %%
#print the digits and count of a number
#include<stdio.h>
void main()
{
 int n,r,c=0;
 scanf("%d",&n);
 while(n!=0)
 {
 c++
 r=n%10;
 printf("%d",r);
 n=n/10;
}
    printf("\n%d",c);
}

# %%
# sum of the digits of a number
#include<stdio.h>
void main()
{
 int n,r,s=0;
 scanf("%d",&n);
 while(n!=0)
 {
 r=n%10;
 s=s+r;
 n=n/10;
}
 printf("%d",s);
}

#reverse of a number
#include<stdio.h>
void main()
{
 int n,r,s=0;
 scanf("%d",&n);
 while(n!=0)
 {
 r=n%10;
 s=s*10+r;
 n=n/10;
}
 printf("%d",s);
}

# %%
#1.palindrom number or not
#include<stdio.h>
void main()
{
 int t,n,r,s=0;
 scanf("%d",&n);
 t=n;
 while(n!=0)
 {
 r=n%10;
 s=s*10+r;
 n=n/10;
}
if (s==t)
 printf("palindrome");
 else 
 printf("not a palindrome");
}
#2. armstrong number or not
#include<stdio.h>
void main()
{
 int t,n,r,c=0,s=0;
 scanf("%d",&n);
 t=n;
 while(n!=0)
 {
     c++;
     t=t/10;
 }
 while(n!=0)
 {
 r=n%10;
 s=s+r*r*r;
 n=n/10;
}
if (s==t)
 printf("armstrong number");
 else 
 printf("not ");
}

#include<stdio.h>
#include<math.h>
void main()
{
 int t,n,r,c=0,s=0;
 scanf("%d",&n);
 t=n;
 while(n!=0)
 {
     c++;
     n=n/10;
 }t=n;
 while(n!=0)
 {
 r=n%10;
 s=s+pow(r,c);
 n=n/10;
}
if (s==t)
 printf("armstrong number");
 else 
 printf("not ");
}

# %%
#palindrome range
#include<stdio.h>
void main()
{
int n,r,s,t,range;
scanf("%d",&range);
for(n=0;n<=range;n++){
t=n;
s=0;
while(t!=0)
{
    r=t%10;
    s=s*10+r;
    t=t/10;
}
if(n==s)
printf(" %d",n);
}
}

# %%
#armstrong range(armstrong no=sum of the powersof each digit with number of digits in a number)
#include<stdio.h>
#include<math.h>
void main()
{
 int t,n,r,c,sum,range;
 scanf("%d",&range);
 for (n=1;n<=range;n++)
 {
 t=n;
 sum=0;
 c=0;
 while (t!=0)
 {
     c++;
     t=t/10;
 }
 t=n;
 while(t!=0)
 {
 r=t%10;
 sum=sum+ceil(pow(r,c));
 t=t/10;
}
if (n==sum)
 printf("%d ",n);
}
}

# %%
# nth palindrome
#include<stdio.h>
void main()
{
int n,r,s,t,range,c=0,k;
scanf("%d",&k);
for(n=0;c<k;n++){
t=n;
s=0;
while(t!=0)
{
    r=t%10;
    s=s*10+r;
    t=t/10;
}
if(n==s)
{c++;
}
}
printf("%d=%d",c,n-1);
}

# %%
#nth prime number and nth fibonacci number

# %%
#sum of the prime number 101 to 500

# %%
#find the no of digits in nth fibonacci number
